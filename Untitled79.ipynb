# %% [markdown]
# <a href="https://colab.research.google.com/github/da0979217/analisis-de-datos/blob/main/Untitled79.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# cargar los datos desde un archivo csv

df=pd.read_csv('/content/escolaridad.csv', encoding='latin1')

print(df.head())

print(df.info())

print(df.describe())

print(df.columns)

df.columns = df.columns.str.strip()

# Mostrar los nombres de las columnas despues de rellenar espacios
print("nombres de las columnas despues de eliminar espacios:")
print(df.columns)

print("Nombres de las columnas:")
print(df.columns)

df.columns = df.columns.str.strip()

print("Nombres de las columnas después de eliminar espacios:")

print(df.columns)

nivel_col = 'nivel_escolaridad'

plt.figure(figsize=(10, 6))

plt.title('Distribución de los Niveles de Escolaridad')
plt.xlabel('Nivel de Escolaridad')
plt.ylabel ('Cantidad')
plt.xticks (rotation=45)
plt.show()
# Out:
#   Instituto Nacional de Estadística y Geografía (INEGI)  \
# 0                                                NaN
# 1             Fecha de consulta: 01/12/2024 14:01:37
# 2
# 3                                           Periodos
# 4                                               2000
#
#                                           Unnamed: 1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Demografía y Sociedad > Educación > Tasa neta ...
# 4                                        49.55943993
#
#                                           Unnamed: 2    Unnamed: 3
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3  Demografía y Sociedad > Educación > Tasa neta ...  6.000000e+09
# ...
